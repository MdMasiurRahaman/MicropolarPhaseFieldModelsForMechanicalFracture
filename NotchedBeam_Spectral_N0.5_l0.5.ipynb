# %%
using Gmsh: gmsh
using Gridap
using GridapGmsh
using Gridap.TensorValues
using PyPlot
using LinearAlgebra

# %%
using  Gmsh: gmsh
const  L = 8.0
const  LL = 0.475.*L
const  LR = 0.525.*L
const  H = 2.0
const  CH = 0.4 #Crack  height
const  CW = 0.2 #Crack  Width
const  lsp = 0.03
const  hfc = lsp/100 #Mesh  size  parameter
const  hf = lsp/2.1 #Mesh  size  parameter
const  h = 100*hf #Mesh  size  parameter
gmsh.initialize()
gmsh.option.setNumber("General.Terminal", 1)
gmsh.model.geo.addPoint((L/2)+(CW/2), 0.0 , 0.0, hf ,1)
gmsh.model.geo.addPoint(L, 0.0, 0.0, h, 2)
gmsh.model.geo.addPoint(L, H, 0.0, h, 3)
gmsh.model.geo.addPoint(LR , H, 0.0, hf, 4)
gmsh.model.geo.addPoint(LL , H, 0.0, hf, 5)
gmsh.model.geo.addPoint(0.0, H, 0.0, h, 6)
gmsh.model.geo.addPoint(0.0, 0.0, 0.0, h, 7)
gmsh.model.geo.addPoint((L/2) -(CW/2), 0.0 , 0.0, hf ,8)
gmsh.model.geo.addPoint((L/2), CH , 0.0, hfc , 9)
gmsh.model.geo.addLine(1, 2, 1)
gmsh.model.geo.addLine(2, 3, 2)
gmsh.model.geo.addLine(3, 4, 3)
gmsh.model.geo.addLine(4, 5, 4)
gmsh.model.geo.addLine(5, 6, 5)
gmsh.model.geo.addLine(6, 7, 6)
gmsh.model.geo.addLine(7, 8, 7)
gmsh.model.geo.addLine(8, 9, 8)
gmsh.model.geo.addLine(9, 1, 9)

gmsh.model.geo.addCurveLoop([1,2,3,4,5,6,7,8,9],1)
gmsh.model.geo.addPlaneSurface([1], 1)
gmsh.model.addPhysicalGroup(2, [1],1)
gmsh.model.addPhysicalGroup(1, [4],1)
gmsh.model.addPhysicalGroup(0, [7],2)
gmsh.model.addPhysicalGroup(0, [2],3)
gmsh.model.setPhysicalName(2, 1, "Domain")
gmsh.model.setPhysicalName(1, 1, "LoadLine")
gmsh.model.setPhysicalName(0, 2, "LeftSupport")
gmsh.model.setPhysicalName(0, 3, "RightSupport")
gmsh.model.mesh.field.add("Box", 10)
gmsh.model.mesh.field.setNumber(10, "VIn", hf)
gmsh.model.mesh.field.setNumber(10, "VOut", h)
gmsh.model.mesh.field.setNumber(10, "XMin", (L/2)-CW)
gmsh.model.mesh.field.setNumber(10, "XMax", (L/2)+CW)
gmsh.model.mesh.field.setNumber(10, "YMin", 0)
gmsh.model.mesh.field.setNumber(10, "YMax", H)
gmsh.model.mesh.field.setAsBackgroundMesh(10)
gmsh.model.geo.synchronize()
gmsh.model.mesh.generate(2)
gmsh.write("BeamWithNotchSymThreePtBending.msh")
gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Line)
# Info    : [ 60%] Meshing curve 6 (Line)
# Info    : [ 70%] Meshing curve 7 (Line)
# Info    : [ 80%] Meshing curve 8 (Line)
# Info    : [ 90%] Meshing curve 9 (Line)
# Info    : Done meshing 1D (Wall 0.0215343s, CPU 0.021534s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.146307s, CPU 0.146285s)
# Info    : 4775 nodes 9557 elements
# Info    : Writing 'BeamWithNotchSymThreePtBending.msh'...
# Info    : Done writing 'BeamWithNotchSymThreePtBending.msh'
# Warning : Unknown entity of dimension 2 and tag 1 in physical group 1
# Warning : Unknown entity of dimension 1 and tag 4 in physical group 1
# Warning : Unknown entity of dimension 0 and tag 7 in physical group 2
# Warning : Unknown entity of dimension 0 and tag 2 in physical group 3

# %%
model = GmshDiscreteModel("BeamWithNotchSymThreePtBending.msh")
writevtk(model,"BeamWithNotchSymThreePtBending")
# Out:
# Info    : Reading 'BeamWithNotchSymThreePtBending.msh'...
# Info    : 19 entities
# Info    : 4775 nodes
# Info    : 9250 elements
# Info    : Done reading 'BeamWithNotchSymThreePtBending.msh'
# 3-element Vector{Vector{String}}:
#  ["BeamWithNotchSymThreePtBending_0.vtu"]
#  ["BeamWithNotchSymThreePtBending_1.vtu"]
#  ["BeamWithNotchSymThreePtBending_2.vtu"]

# %%
using Gridap.Geometry
labels = get_face_labeling(model)
dimension = 2
mat_tags = get_face_tag(labels,dimension)
# Out:
# 9220-element Vector{Int8}:
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  ⋮
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4
#  4

# %%
const E = 20.8
const ν = 0.3
const Gc = 5e-4
G = E/(2*(1+ν))
l = 0.5
N = 0.5
const η = 1e-15
# Out:
# 1.0e-15

# %%
ψ_crit = 10.0
# Out:
# 10.0

# %%
μ = 5.33333333333333
κ = 5.33333333333333
λ = 11.999999999999993
γ = 7.999999999999996
# Out:
# 7.999999999999996

# %%
function Eigen(ε)
    εArray = get_array(ε)
    Λ, P = eigen(εArray)
    ε1 = Λ[1]
    ε2 = Λ[2]
    if ε1 >= 0 &&  ε2 >= 0
        Λpos = [ε1 0; 0 ε2]
        Λneg = [0 0; 0 0]
    elseif ε1 >= 0 &&  ε2 < 0
        Λpos = [ε1 0; 0 0]
        Λneg = [0 0; 0 ε2]
    elseif ε1 < 0 &&  ε2 >= 0
        Λpos = [0 0; 0 ε2]
        Λneg = [ε1 0; 0 0]
    elseif ε1 < 0 &&  ε2 < 0
        Λpos = [0 0; 0 0]
        Λneg = [ε1 0; 0 ε2]
    end 
    εPos = TensorValue(P*Λpos*P')
    εNeg = TensorValue(P*Λneg*P')
    if tr(ε) >= 0
        ψPos = 0.5*(λ*(tr(ε))^2 + (2*μ+κ)*(εPos ⊙ εPos))
        ψNeg = 0.5*(2*μ+κ)*(εNeg ⊙ εNeg)
    else
        ψPos = 0.5*((2*μ+κ)*(εPos ⊙ εPos))
        ψNeg = 0.5*(λ*(tr(ε))^2 +(2*μ+κ)*(εNeg ⊙ εNeg))
    end
    if ψPos >= ψNeg
        case = 1
    else
        case = 2
    end
    return case, ψPos, ψNeg 
end
# Out:
# Eigen (generic function with 1 method)

# %%
function σ_Bmod(ε, ε_in, s_in)
    case, ψP, ψN = Eigen(ε_in)
    if case == 1
        σM = (s_in^2 + η)*(λ*tr(ε)*one(ε) + (2*μ + κ)*(ε))
    else
        σM = (λ*tr(ε)*one(ε) + (2*μ + κ)*(ε))
    end
    return σM
end
# Out:
# σ_Bmod (generic function with 1 method)

# %%
E_Matrx = TensorValue(0,1,-1,0)
# Out:
# TensorValue{2, 2, Int64, 4}(0, 1, -1, 0)

# %%
function ε_Skw(∇,θ)
    ∇ᵀ = transpose(∇)
    w = (0.5*(∇ᵀ - ∇)) - (E_Matrx*θ)
    return w
end
# Out:
# ε_Skw (generic function with 1 method)

# %%
function σ_Cmod(ϵ_skew, s_in)
    σM = (s_in^2 + η)*(κ*ϵ_skew)
    return σM
end
# Out:
# σ_Cmod (generic function with 1 method)

# %%
function M_mod(∇, s_in)
    M = (s_in^2 + η)*(γ*∇)
    return M
end
# Out:
# M_mod (generic function with 1 method)

# %%
function ψPos(ε_in,∇_uh,θ, ∇_th)
    ∇_uhᵀ = transpose(∇_uh)
    ϵ_skew = 0.5*(∇_uhᵀ - ∇_uh) - E_Matrx*θ
    case, ψP, ψN = Eigen(ε_in)
    ψPos = ψP + 0.5*(κ*(ϵ_skew ⊙ ϵ_skew)) + 0.5*γ*(∇_th ⋅ ∇_th)
    return ψPos 
end
# Out:
# ψPos (generic function with 1 method)

# %%
function new_EnergyState(ψPlusPrev_in,ψhPos_in)
    ψPlus_in = ψhPos_in
    if ψPlus_in >= ψPlusPrev_in
        ψPlus_out = ψPlus_in
    else
        ψPlus_out = ψPlusPrev_in
    end
    true,ψPlus_out
end
# Out:
# new_EnergyState (generic function with 1 method)

# %%
function project(q,model,dΩ,order)
  reffe = ReferenceFE(lagrangian,Float64,order)
  V = FESpace(model,reffe,conformity=:L2)
  a(u,v) = ∫( u*v )*dΩ
  l(v) = ∫( v*q )*dΩ
  op = AffineFEOperator(a,l,V,V)
  qh = solve(op)
  qh
end
# Out:
# project (generic function with 1 method)

# %%
order = 1
degree = 2*order
# Out:
# 2

# %%
Ω = Triangulation(model)
dΩ = Measure(Ω,degree)
# Out:
# Measure()

# %%
sId = CellState(1.0,dΩ)
shId = project(sId,model,dΩ,order)
# Out:
# SingleFieldFEFunction():
#  num_cells: 9220
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 18258850968802414530

# %%
LoadTagId = get_tag_from_name(labels,"LoadLine")
Γ_Load = BoundaryTriangulation(model,tags = LoadTagId)
dΓ_Load = Measure(Γ_Load,degree)
n_Γ_Load = get_normal_vector(Γ_Load)
# Out:
# GenericCellField():
#  num_cells: 28
#  DomainStyle: ReferenceDomain()
#  Triangulation: BoundaryTriangulation()
#  Triangulation id: 44830638291562697

# %%
reffe_PF = ReferenceFE(lagrangian,Float64,order)
V0_PF = TestFESpace(model,reffe_PF;conformity=:H1)
sh = zero(V0_PF)
# Out:
# SingleFieldFEFunction():
#  num_cells: 9220
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 18258850968802414530

# %%
reffe_theta = ReferenceFE(lagrangian,Float64,order)
V0_theta  = TestFESpace(model,reffe_theta;
  conformity=:H1)
θh = zero(V0_theta)
# Out:
# SingleFieldFEFunction():
#  num_cells: 9220
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 18258850968802414530

# %%
reffe_Disp = ReferenceFE(lagrangian,VectorValue{2,Float64},order)
        V0_Disp = TestFESpace(model,reffe_Disp;
          conformity=:H1,
          dirichlet_tags=["LeftSupport","RightSupport","LoadLine"],
          dirichlet_masks=[(false, true), (true, true), (false, true)])

uh = zero(V0_Disp)
# Out:
# SingleFieldFEFunction():
#  num_cells: 9220
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 18258850968802414530

# %%
V0 = MultiFieldFESpace([V0_Disp,V0_theta])
# Out:
# MultiFieldFESpace()

# %%
function  stepPhaseField(uh_in,ψPlusPrev_in)
    U_PF = TrialFESpace(V0_PF)
        a_PF(s,ϕ) = ∫( (Gc*lsp*∇(ϕ)⋅ ∇(s)) + (2*ψPlusPrev_in*s*ϕ)  + ((Gc/lsp)*s*ϕ) )*dΩ
        b_PF(ϕ) = ∫( (Gc/lsp)*ϕ )*dΩ
        op_PF = AffineFEOperator(a_PF,b_PF,U_PF,V0_PF)
        sh_out = solve(op_PF)
    return sh_out
end
# Out:
# stepPhaseField (generic function with 1 method)

# %%
function Skw(u,θ)
    ∇ᵀ = transpose(∇(u))
    w = (0.5*(∇ᵀ - ∇(u)) - (E_Matrx*θ))
    return w
end
# Out:
# Skw (generic function with 1 method)

# %%
function   stepDisp(uh_in,θ_in,sh_in,uApp)
        uApp1(x) = VectorValue(0.0,0.0)
        uApp2(x) = VectorValue(0.0,0.0)
        uApp3(x) = VectorValue(0.0,-uApp)
        U_Disp = TrialFESpace(V0_Disp,[uApp1,uApp2,uApp3])
        
        U_theta = TrialFESpace(V0_theta)
        U = MultiFieldFESpace([U_Disp,U_theta ])

        a((u,θ),(w,v))  = ∫( (ε(w) ⊙ (σ_Bmod∘(ε(u),ε(uh_in),sh_in)) ) + ((Skw(w,v)) ⊙ (σ_Cmod∘(ε_Skw∘(∇(u),θ), sh_in)) ) + ((∇(v))⋅ (M_mod∘(∇(θ),sh_in))) - (v*((E_Matrx) ⊙ (σ_Cmod∘(ε_Skw∘(∇(u),θ),sh_in))) ))*dΩ
        b((w,v))= 0
        op_Disp = AffineFEOperator(a,b,U,V0)
        uh_out = solve(op_Disp)
        uh_out,phih_out = uh_out
    return uh_out, phih_out
end
# Out:
# stepDisp (generic function with 1 method)

# %%
cd("Results_N0.5_l0.5")

# %%
uApp = 0
delu = 1e-3
uAppMax = 0.1
innerMax = 10
count = 0
Load = Float64[]
Displacement = Float64[]

sPrev = CellState(1.0,dΩ)
sh = project(sPrev,model,dΩ,order)
ψPlusPrev = CellState(0.0,dΩ)
ψhPos = CellState(0.0,dΩ)
ψhPos_in = project(ψhPos,model,dΩ,order)

while uApp .< uAppMax 
        
    uApp = uApp .+ delu
    count = count .+ 1
    if uApp >= 3e-2
        delv = 1e-4
    end
   
    print("\n Entering displacemtent step$count :", float(uApp))
    
   for inner = 1:innerMax
        
        ψhPlusPrev = project(ψPlusPrev,model,dΩ,order)
        
        err = abs(sum(∫( Gc*lsp*∇(sh)⋅ ∇(sh) + 2*ψhPlusPrev*sh*sh  + (Gc/lsp)*sh*sh)*dΩ - ∫( (Gc/lsp)*sh)*dΩ))/abs(sum(∫( (Gc/lsp)*sh)*dΩ))
        print("\n Relative error = ",float(err))
        
        sh = stepPhaseField(uh,ψhPlusPrev) 
        uh,θh = stepDisp(uh,θh,sh,uApp)
        
        ψhPos_in = ψPos∘(ε(uh),∇(uh),θh,∇(θh))      
        
        update_state!(new_EnergyState,ψPlusPrev,ψhPos_in)
        
        if err < 1e-8
            break 
        end
    end
    
    Node_Force = sum(∫( n_Γ_Load ⋅ (σ_Bmod∘(ε(uh),ε(uh),sh)) ) *dΓ_Load + ∫( n_Γ_Load ⋅ (σ_Cmod∘(ε_Skw∘(∇(uh),θh),sh) ) )  *dΓ_Load)
    
    push!(Load, Node_Force[2])
    push!(Displacement, uApp)
    if mod(count,10) == 0
         writevtk(Ω,"results_PhaseFieldNotchedBeam_Spectral$count",cellfields=
        ["uh"=>uh,"s"=>sh ,"θ" => θh, "epsi"=>ε(uh)])
    end
end
# Out:
#  Entering displacemtent step1 :0.001
#  Relative error = 7.43106511516683e-17
#  Entering displacemtent step2 :0.002
#  Relative error = 5.406571692273184e-6
#  Relative error = 1.6219580867939836e-5
#  Relative error = 2.2771015134069136e-9
#  Entering displacemtent step3 :0.003
#  Relative error = 2.961936777953489e-12
#  Entering displacemtent step4 :0.004
#  Relative error = 2.7030145449634752e-5
#  Relative error = 3.7845258329188825e-5
#  Relative error = 2.131356711121676e-8
#  Relative error = 1.1129256989504513e-10
#  Entering displacemtent step5 :0.005
#  Relative error = 7.834865256493853e-13
#  Entering displacemtent step6 :0.006
#  Relative error = 4.863684833559817e-5
#  Relative error = 5.947149979553784e-5
#  Relative error = 7.587808398094299e-8
#  Relative error = 8.967866977797188e-10
#  Entering displacemtent step7 :0.007
#  Relative error = 1.4287334057754242e-11
#  Entering displacemtent step8 :0.008
#  Relative error = 7.02088378536759e-5
#  Relative error = 8.109951288993131e-5
#  Relative error = 1.8597163474935715e-7
#  Relative error = 4.029483592878741e-9
#  Entering displacemtent step9 :0.009000000000000001
#  Relative error = 1.1277861338375177e-10
#  Entering displacemtent step10 :0.010000000000000002
#  Relative error = 9.172650456790105e-5
#  Relative error = 0.0001027305117943517
#  Relative error = 3.737125237921475e-7
#  Relative error = 1.2538659593978472e-8
#  Relative error = 5.64998171810375e-10
#  Entering displacemtent step11 :0.011000000000000003
#  Relative error = 2.6981293970598735e-11
#  Entering displacemtent step12 :0.012000000000000004
#  Relative error = 0.00011316753702101327
#  Relative error = 0.00012436568474087536
#  Relative error = 6.642153614839081e-7
#  Relative error = 3.2605366460562304e-8
#  Relative error = 2.142726544999278e-9
#  Entering displacemtent step13 :0.013000000000000005
#  Relative error = 1.4914705430909247e-10
#  Entering displacemtent step14 :0.014000000000000005
#  Relative error = 0.0001345047449786297
#  Relative error = 0.00014600624784745142
#  Relative error = 1.0869921031862185e-6
#  Relative error = 7.40270904065295e-8
#  Relative error = 6.727263590809886e-9
#  Entering displacemtent step15 :0.015000000000000006
#  Relative error = 6.468997820409505e-10
#  Entering displacemtent step16 :0.016000000000000007
#  Relative error = 0.00015570420980024803
#  Relative error = 0.0001676534051097224
#  Relative error = 1.677616515629799e-6
#  Relative error = 1.5265331755035936e-7
#  Relative error = 1.846443237788383e-8
#  Relative error = 2.3608936171096813e-9
#  Entering displacemtent step17 :0.017000000000000008
#  Relative error = 3.0622558384237264e-10
#  Entering displacemtent step18 :0.01800000000000001
#  Relative error = 0.00017672099698602298
#  Relative error = 0.0001893083184128513
#  Relative error = 2.4799843658635076e-6
#  Relative error = 2.933442386247655e-7
#  Relative error = 4.591167716617276e-8
#  Relative error = 7.590251811856621e-9
#  Entering displacemtent step19 :0.01900000000000001
#  Relative error = 1.272782198263808e-9
#  Entering displacemtent step20 :0.02000000000000001
#  Relative error = 0.0001974936665531015
#  Relative error = 0.00021097204800517896
#  Relative error = 3.5494825422995118e-6
#  Relative error = 5.346959739084988e-7
#  Relative error = 1.0605227083116993e-7
#  Relative error = 2.220237638727233e-8
#  Relative error = 4.714161543068907e-9
#  Entering displacemtent step21 :0.02100000000000001
#  Relative error = 1.0052135688398902e-9
#  Entering displacemtent step22 :0.022000000000000013
#  Relative error = 0.0002179324144409249
#  Relative error = 0.0002326452953773504
#  Relative error = 4.958074040249118e-6
#  Relative error = 9.389377178672642e-7
#  Relative error = 2.3193737064680679e-7
#  Relative error = 6.05550034805369e-8
#  Relative error = 1.603716370963275e-8
#  Relative error = 4.265563400874274e-9
#  Entering displacemtent step23 :0.023000000000000013
#  Relative error = 1.1361194014173862e-9
#  Entering displacemtent step24 :0.024000000000000014
#  Relative error = 0.00023789856541691994
#  Relative error = 0.00025432821015775606
#  Relative error = 6.808742995977253e-6
#  Relative error = 1.6073201171062553e-6
#  Relative error = 4.876647641982539e-7
#  Relative error = 1.5710708650261964e-7
#  Relative error = 5.135776051392166e-8
#  Relative error = 1.686543539183415e-8
#  Relative error = 5.54683353419481e-9
#  Entering displacemtent step25 :0.025000000000000015
#  Relative error = 1.82522191656526e-9
#  Entering displacemtent step26 :0.026000000000000016
#  Relative error = 0.0002571536638015684
#  Relative error = 0.0002760194903209767
#  Relative error = 9.226067242746105e-6
#  Relative error = 2.6640040722591012e-6
#  Relative error = 9.97235215292116e-7
#  Relative error = 3.941147389207505e-7
#  Relative error = 1.5804752168277467e-7
#  Relative error = 6.373751005815816e-8
#  Relative error = 2.575234494919452e-8
#  Relative error = 1.0411904232589194e-8
#  Entering displacemtent step27 :0.027000000000000017
#  Relative error = 4.210707434340534e-9
#  Entering displacemtent step28 :0.028000000000000018
#  Relative error = 0.0002753106087308075
#  Relative error = 0.00029771085991525003
#  Relative error = 1.2423285308197389e-5
#  Relative error = 4.40829842895433e-6
#  Relative error = 2.0165144484490575e-6
#  Relative error = 9.74629941814823e-7
#  Relative error = 4.79608439149792e-7
#  Relative error = 2.3747355050032794e-7
#  Relative error = 1.1802830286803079e-7
#  Relative error = 5.863595377641697e-8
#  Entering displacemtent step29 :0.02900000000000002
#  Relative error = 2.9244316142190466e-8
#  Relative error = 0.0002914491950364226
#  Relative error = 1.1042233605374816e-5
#  Relative error = 4.1342315841837405e-6
#  Relative error = 2.081465363611155e-6
#  Relative error = 1.1165437017285212e-6
#  Relative error = 6.107983482796515e-7
#  Relative error = 3.366428184966523e-7
#  Relative error = 1.8613685282692466e-7
#  Relative error = 1.0307147308318268e-7
#  Entering displacemtent step30 :0.03000000000000002
#  Relative error = 5.711811141128965e-8
#  Relative error = 0.00030250040133772985
#  Relative error = 1.2567993316724841e-5
#  Relative error = 5.216881660560981e-6
#  Relative error = 2.9179761292343693e-6
#  Relative error = 1.7421258996227181e-6
#  Relative error = 1.0623910971622294e-6
#  Relative error = 6.536061454859429e-7
#  Relative error = 4.038147947776672e-7
#  Relative error = 2.500858292401475e-7
#  Entering displacemtent step31 :0.03100000000000002
#  Relative error = 1.550865196343632e-7
#  Relative error = 0.000309313594689292
#  Relative error = 1.4264927827546998e-5
#  Relative error = 6.641790555084795e-6
#  Relative error = 4.169840260446013e-6
#  Relative error = 2.7784154429298006e-6
#  Relative error = 1.8998890594479437e-6
#  Relative error = 1.3134583681235888e-6
#  Relative error = 9.136646699142576e-7
#  Relative error = 6.380602203371682e-7
#  Entering displacemtent step32 :0.03200000000000002
#  Relative error = 4.466481209560343e-7
#  Relative error = 0.00031415845151829436
#  Relative error = 1.628201148384207e-5
#  Relative error = 8.631561030322333e-6
#  Relative error = 6.1045540167071955e-6
#  Relative error = 4.608679440557722e-6
#  Relative error = 3.5706327970347678e-6
#  Relative error = 2.805711373400662e-6
#  Relative error = 2.2251692778376586e-6
#  Relative error = 1.7767730316023363e-6
#  Entering displacemtent step33 :0.03300000000000002
#  Relative error = 1.4262499143001633e-6
#  Relative error = 0.00031517981171532285
#  Relative error = 1.9120883681176116e-5
#  Relative error = 1.1886066449856903e-5
#  Relative error = 9.683785616249638e-6
#  Relative error = 8.411937224877328e-6
#  Relative error = 7.518803165019944e-6
#  Relative error = 6.933041215542765e-6
#  Relative error = 6.325336150320395e-6
#  Relative error = 5.915536762710935e-6
#  Entering displacemtent step34 :0.03400000000000002
#  Relative error = 5.59184248729541e-6
#  Relative error = 0.0003082207683289092
#  Relative error = 2.6307143269624304e-5
#  Relative error = 2.033965292420409e-5
#  Relative error = 1.9702440861657827e-5
#  Relative error = 2.0143732641446093e-5
#  Relative error = 2.1104499310313273e-5
#  Relative error = 2.247169755111974e-5
#  Relative error = 2.4030373535199654e-5
#  Relative error = 2.5799293475294676e-5
#  Entering displacemtent step35 :0.035000000000000024
#  Relative error = 2.7560876803554204e-5
#  Relative error = 0.0002807132325363744
#  Relative error = 5.547626543474874e-5
#  Relative error = 4.852778810311187e-5
#  Relative error = 4.638708802083122e-5
#  Relative error = 4.411133274984657e-5
#  Relative error = 4.170315579815615e-5
#  Relative error = 3.9377702104612844e-5
#  Relative error = 3.712025531273614e-5
#  Relative error = 3.494381583892759e-5
#  Entering displacemtent step36 :0.036000000000000025
#  Relative error = 3.3053869342907954e-5
#  Relative error = 0.00024360998928221194
#  Relative error = 5.8677941672321893e-5
#  Relative error = 4.88719594844513e-5
#  Relative error = 4.5890851130478016e-5
#  Relative error = 4.433518314316305e-5
#  Relative error = 4.388843785553108e-5
#  Relative error = 4.4161678964152444e-5
#  Relative error = 4.4285427809797726e-5
#  Relative error = 4.3712381705868035e-5
#  Entering displacemtent step37 :0.037000000000000026
#  Relative error = 4.2656730388956794e-5
#  Relative error = 0.00025581237680887215
#  Relative error = 7.42126443165296e-5
#  Relative error = 6.63064273497803e-5
#  Relative error = 6.514023908344846e-5
#  Relative error = 6.413316565220021e-5
#  Relative error = 6.339464947555715e-5
#  Relative error = 6.308280146003189e-5
#  Relative error = 6.365917317946839e-5
#  Relative error = 6.507982447336853e-5
#  Entering displacemtent step38 :0.03800000000000003
#  Relative error = 6.674761024851581e-5
#  Relative error = 0.0002774606796059108
#  Relative error = 0.00010328851036225122
#  Relative error = 9.364657360346898e-5
#  Relative error = 9.271755727088182e-5
#  Relative error = 9.435619418824146e-5
#  Relative error = 9.585302397700675e-5
#  Relative error = 9.578545954168775e-5
#  Relative error = 9.533701932308392e-5
#  Relative error = 9.619492091551646e-5
#  Entering displacemtent step39 :0.03900000000000003
#  Relative error = 9.854916052422402e-5
#  Relative error = 0.0003072440598631896
#  Relative error = 0.00014145143575528094
#  Relative error = 0.0001319505164183688
#  Relative error = 0.00013176432574178796
#  Relative error = 0.0001326083592345914
#  Relative error = 0.00013236115538903937
#  Relative error = 0.00013271337013205355
#  Relative error = 0.00013372125071240597
#  Relative error = 0.00013365482031586252
#  Entering displacemtent step40 :0.04000000000000003
#  Relative error = 0.00013360005738279027
#  Relative error = 0.0003395245026169622
#  Relative error = 0.00018184270875625446
#  Relative error = 0.00017145691248177225
#  Relative error = 0.00016991404002455435
#  Relative error = 0.00016851998552789782
#  Relative error = 0.00016744980118426803
#  Relative error = 0.00016668255571754877
#  Relative error = 0.00016471998862374246
#  Relative error = 0.00016415083840885127
#  Entering displacemtent step41 :0.04100000000000003
#  Relative error = 0.0001635829567334747
#  Relative error = 0.00035883823488841275
#  Relative error = 0.0002124102280950074
#  Relative error = 0.00019946450549795336
#  Relative error = 0.0001957688399455836
#  Relative error = 0.00019321826102539666
#  Relative error = 0.00019028535904943252
#  Relative error = 0.00018791260920244423
#  Relative error = 0.0001848540396006081
#  Relative error = 0.0001832521821165168
#  Entering displacemtent step42 :0.04200000000000003
#  Relative error = 0.00018110857093841436
#  Relative error = 0.00036026870373522495
#  Relative error = 0.0002284606635142548
#  Relative error = 0.00021247799637999455
#  Relative error = 0.000207503365684488
#  Relative error = 0.00020272140129251696
#  Relative error = 0.00019952919875662305
#  Relative error = 0.00019648476336002235
#  Relative error = 0.00019380437791234796
#  Relative error = 0.00019204555750920835
#  Entering displacemtent step43 :0.04300000000000003
#  Relative error = 0.00018873325229280217
#  Relative error = 0.00034711310781605423
#  Relative error = 0.00023560138891424222
#  Relative error = 0.00022062193993506343
#  Relative error = 0.00021380496568622275
#  Relative error = 0.00020948631171161284
#  Relative error = 0.00020538881778582325
# InterruptException:
#
# Stacktrace:
#   [1] Eigen(ε::SymTensorValue{2, Float64, 3})
#     @ Main ./In[8]:33
#   [2] σ_Bmod(ε::SymTensorValue{2, Float64, 3}, ε_in::SymTensorValue{2, Float64, 3}, s_in::Float64)
#     @ Main ./In[9]:2
#   [3] _broadcast_getindex_evalf
#     @ ./broadcast.jl:670 [inlined]
#   [4] _broadcast_getindex
#     @ ./broadcast.jl:643 [inlined]
#   [5] getindex
#     @ ./broadcast.jl:597 [inlined]
#   [6] macro expansion
#     @ ./broadcast.jl:961 [inlined]
#   [7] macro expansion
#     @ ./simdloop.jl:77 [inlined]
#   [8] copyto!
#     @ ./broadcast.jl:960 [inlined]
#   [9] copyto!
#     @ ./broadcast.jl:913 [inlined]
#  [10] materialize!
#     @ ./broadcast.jl:871 [inlined]
#  [11] materialize!
#     @ ./broadcast.jl:868 [inlined]
#  [12] broadcast!(::typeof(σ_Bmod), ::Array{SymTensorValue{2, Float64, 3}, 3}, ::Array{SymTensorValue{2, Float64, 3}, 3}, ::Vector{SymTensorValue{2, Float64, 3}}, ::Vector{Float64})
#     @ Base.Broadcast ./broadcast.jl:837
#  [13] evaluate!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/Maps.jl:162 [inlined]
#  [14] evaluate!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Fields/FieldArrays.jl:502 [inlined]
#  [15] evaluate!(::Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, ::Gridap.Fields.BroadcastingFieldOpMap{typeof(σ_Bmod)}, ::Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, ::Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, ::Gridap.Fields.MatrixBlock{Vector{Float64}})
#     @ Gridap.Fields ~/.julia/packages/Gridap/TyUsh/src/Fields/ArrayBlocks.jl:958
#  [16] evaluate!(::Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, ::Gridap.Fields.BroadcastingFieldOpMap{typeof(σ_Bmod)}, ::Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, ::Vector{SymTensorValue{2, Float64, 3}}, ::Vector{Float64})
#     @ Gridap.Fields ~/.julia/packages/Gridap/TyUsh/src/Fields/ArrayBlocks.jl:1025
#  [17] _getindex_and_call!(cgi::Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(σ_Bmod)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{SymTensorValue{2, Float64, 3}, Vector{SymTensorValue{2, Float64, 3}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}, Tuple{Gridap.Arrays.CachedVector{Int32, Vector{Int32}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{Float64}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Grid ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:340
#  [18] getindex!(cache::Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{SymTensorValue{2, Float64, 3}, Vector{SymTensorValue{2, Float64, 3}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}, Tuple{Gridap.Arrays.CachedVector{Int32, Vector{Int32}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{Float64}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214
#  [19] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(inner)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Gridap ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:332
#  [20] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [21] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(+)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Flo ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:331
#  [22] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [23] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(+)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{ ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:331
#  [24] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [25] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(-)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{ ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:331
#  [26] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [27] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Matrix{Float64}}, Matrix{Tuple{Gridap.Arrays.CachedMatrix{Float64, Matrix{Float64}}, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, gi::Gridap.Fields.IntegrationMap, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tup ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:337
#  [28] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [29] _getindex_and_call!(cgi::Tuple{Tuple{Gridap.Fields.VectorBlock{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Nothing}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, gi::Gridap.CellData.AttachDirichletMap, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Matrix{Float64}}, Matrix{Tuple{Gridap.Arrays.CachedMatrix{Float64, Matrix{Float64}}, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Ma ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:337
#  [30] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [31] _numeric_loop_matvec!(A::Gridap.Algebra.InserterCSC{Float64, Int64}, b::Vector{Float64}, caches::Tuple{Matrix{Nothing}, Vector{Nothing}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.VectorBlock{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Nothing}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Matrix{Float64}}, Matrix{Tuple{Gridap.Arrays.CachedMatrix{Float64, Matrix{Float64}}, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, ...
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/SparseMatrixAssemblers.jl:363
#  [32] numeric_loop_matrix_and_vector!(A::Gridap.Algebra.InserterCSC{Float64, Int64}, b::Vector{Float64}, a::Gridap.FESpaces.GenericSparseMatrixAssembler, data::Tuple{Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/SparseMatrixAssemblers.jl:349
#  [33] assemble_matrix_and_vector(a::Gridap.FESpaces.GenericSparseMatrixAssembler, data::Tuple{Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/SparseMatrixAssemblers.jl:137
#  [34] AffineFEOperator(weakform::Gridap.FESpaces.var"#60#61"{var"#a#8"{Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}}, var"#b#9"}, trial::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, test::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, assem::Gridap.FESpaces.GenericSparseMatrixAssembler)
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/AffineFEOperators.jl:38
#  [35] AffineFEOperator(::Function, ::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, ::Vararg{MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/AffineFEOperators.jl:47
#  [36] AffineFEOperator(::var"#a#8"{Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}}, ::var"#b#9", ::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, ::Vararg{MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/AffineFEOperators.jl:51
#  [37] stepDisp(uh_in::Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, θ_in::Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, sh_in::Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, uApp::Float64)
#     @ Main ./In[27]:12
#  [38] top-level scope
#     @ ./In[29]:33
#  [39] eval
#     @ ./boot.jl:368 [inlined]
#  [40] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1428

# %%
writevtk(Ω,"results_PhaseFieldNotchedBeam_Spectral$count",cellfields=
        ["uh"=>uh,"s"=>sh ,"θ" => θh, "epsi"=>ε(uh)])
# Out:
# (["results_PhaseFieldNotchedBeam_Spectral43.vtu"],)

# %%
plot(Displacement,-Load)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f7b1ea772b0>

# %%
cd("../DispLoadData_THreePointBending_Spectral")

# %%
using DelimitedFiles
Disp = writedlm( "DispDataNotchedBeam_SpectralN0.5_l0.5.csv",  Displacement, ',')
Force = writedlm("LoadDataNotchedBeam_SpectralN0.5_l0.5.csv",  Load, ',')
