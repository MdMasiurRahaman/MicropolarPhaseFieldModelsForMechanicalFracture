# %%
using Gmsh: gmsh
using Gridap
using GridapGmsh
using Gridap.TensorValues
using PyPlot
using LinearAlgebra

# %%
I2 = SymTensorValue{2,Float64}(1.0 ,0.0 ,1.0)
I4 = I2⊗I2
I4_sym = one(SymFourthOrderTensorValue{2,Float64})
I4_vol = (1.0/2)*I4
I4_dev = I4_sym  - I4_vol
# Out:
# SymFourthOrderTensorValue{2, Float64, 9}(0.5, 0.0, -0.5, 0.0, 0.5, 0.0, -0.5, 0.0, 0.5)

# %%
const L = 100
const CH = 25         #Crack height
const CW = 0.01*CH    #Crack Width
const hf = CH/100     #Mesh size parameter
const hfc = hf/4      #Mesh size parameter
const h = 10*hf       #Mesh size parameter
const lsp = hf*2.1

gmsh.initialize()
gmsh.option.setNumber("General.Terminal", 1)

p1 = gmsh.model.geo.addPoint(0.0, 0.0, 0.0, h)
p2 = gmsh.model.geo.addPoint(L, 0, 0.0, h)
p3 = gmsh.model.geo.addPoint(L, 0.5*(L-CW), 0.0, h)
p4 = gmsh.model.geo.addPoint(L-CH, 0.5*(L-CW), 0.0, hfc)
p5 = gmsh.model.geo.addPoint(L-CH, 0.5*(L+CW), 0.0, hfc)
p6 = gmsh.model.geo.addPoint(L, 0.5*(L+CW), 0.0, h)
p7 = gmsh.model.geo.addPoint(L, L, 0.0, h)
p8 = gmsh.model.geo.addPoint(0.0, L, 0.0, h)
p9 = gmsh.model.geo.addPoint(0.0, 0.5*(L+CW), 0.0, h)
p10 = gmsh.model.geo.addPoint(CH, 0.5*(L+CW), 0.0, hfc)
p11 = gmsh.model.geo.addPoint(CH, 0.5*(L-CW), 0.0, hfc)
p12 = gmsh.model.geo.addPoint(0.0, 0.5*(L-CW), 0.0, h)

l1 = gmsh.model.geo.addLine(p1, p2)
l2 = gmsh.model.geo.addLine(p2, p3)
l3 = gmsh.model.geo.addLine(p3, p4)
l4 = gmsh.model.geo.addLine(p4, p5)
l5 = gmsh.model.geo.addLine(p5, p6)
l6 = gmsh.model.geo.addLine(p6, p7)
l7 = gmsh.model.geo.addLine(p7, p8)
l8 = gmsh.model.geo.addLine(p8, p9)
l9 = gmsh.model.geo.addLine(p9, p10)
l10 = gmsh.model.geo.addLine(p10, p11)
l11 = gmsh.model.geo.addLine(p11, p12)
l12 = gmsh.model.geo.addLine(p12, p1)

cl1 = gmsh.model.geo.addCurveLoop([l1,l2,l3,l4,l5,l6,l7,l8,l9,l10,l11,l12])
ps1 = gmsh.model.geo.addPlaneSurface([cl1])

pg1 = gmsh.model.addPhysicalGroup(2, [ps1])

pg2 = gmsh.model.addPhysicalGroup(1, [l1])
pg3 = gmsh.model.addPhysicalGroup(1, [l7])

gmsh.model.setPhysicalName(2, pg1, "Domain")
gmsh.model.setPhysicalName(1, pg2, "DirichletBottom")
gmsh.model.setPhysicalName(1, pg3, "LoadLine")

gmsh.model.mesh.field.add("Box", 11)
gmsh.model.mesh.field.setNumber(11, "VIn", hf)
gmsh.model.mesh.field.setNumber(11, "VOut", h)
gmsh.model.mesh.field.setNumber(11, "XMin", 0.5*(L-3*CH))
gmsh.model.mesh.field.setNumber(11, "XMax", 0.5*(L+3*CH))
gmsh.model.mesh.field.setNumber(11, "YMin", 0.5*(L-2*CH))
gmsh.model.mesh.field.setNumber(11, "YMax", 0.5*(L+2*CH))

gmsh.model.mesh.field.setAsBackgroundMesh(11)

gmsh.model.geo.synchronize()
gmsh.model.mesh.generate(2)
gmsh.write("DoubleEdgeNotch.msh")
gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 50%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.00844913s, CPU 0.008362s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 2.67399s, CPU 2.64689s)
# Info    : 69936 nodes 139882 elements
# Info    : Writing 'DoubleEdgeNotch.msh'...
# Info    : Done writing 'DoubleEdgeNotch.msh'
# Warning : Unknown entity of dimension 2 and tag 1 in physical group 1
# Warning : Unknown entity of dimension 1 and tag 1 in physical group 2
# Warning : Unknown entity of dimension 1 and tag 7 in physical group 3

# %%
model = GmshDiscreteModel("DoubleEdgeNotch.msh")
writevtk(model,"DoubleEdgeNotch")
# Out:
# Info    : Reading 'DoubleEdgeNotch.msh'...
# Info    : 25 entities
# Info    : 69936 nodes
# Info    : 139518 elements
# Info    : Done reading 'DoubleEdgeNotch.msh'
# 3-element Vector{Vector{String}}:
#  ["DoubleEdgeNotch_0.vtu"]
#  ["DoubleEdgeNotch_1.vtu"]
#  ["DoubleEdgeNotch_2.vtu"]

# %%
using Gridap.Geometry
labels = get_face_labeling(model)
dimension = 2
mat_tags = get_face_tag(labels,dimension)
# Out:
# 139438-element Vector{Int8}:
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  ⋮
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3

# %%
const G = 12.5e3
const ν = 0.2
const E = G*(2*(1+ν))
l = 30.0
N = 0.0
Gc = 0.1

const η = 1e-15
# Out:
# 1.0e-15

# %%
μ = 8333.33333333333
κ = 8333.33333333333
λ = 8333.33333333333
γ = 4.4999999999999985e7
# Out:
# 4.4999999999999985e7

# %%
function σ_Bmod(ε, ε_in, s_in)
    if tr(ε_in) >= 0
        σM = (s_in^2 + η)*((λ + μ + (κ/2))*tr(ε)*one(ε) + (2*μ + κ)*(I4_dev ⊙ ε))
    else
        σM = (s_in^2 + η)*((2*μ + κ)*(I4_dev ⊙ ε)) + (λ + μ + (κ/2))*tr(ε)*one(ε)
    end
    return σM
end
# Out:
# σ_Bmod (generic function with 1 method)

# %%
E_Matrx = TensorValue(0,-1,1,0)
# Out:
# TensorValue{2, 2, Int64, 4}(0, -1, 1, 0)

# %%
function ε_Skw(∇,θ)
    ∇ᵀ = transpose(∇)
    w = (0.5*(∇ᵀ - ∇)) - (E_Matrx*θ)
    return w
end
# Out:
# ε_Skw (generic function with 1 method)

# %%
function σ_Cmod(ϵ_skew, s_in)
    σM = gd(s_in)*(κ*ϵ_skew)
    return σM
end
# Out:
# σ_Cmod (generic function with 1 method)

# %%
function M_mod(∇, s_in)
    M = gd(s_in)*(γ*∇)
    return M
end
# Out:
# M_mod (generic function with 1 method)

# %%
function gd(s_in)
    M = s_in^2
    return M
end
# Out:
# gd (generic function with 1 method)

# %%
function ψPos(ε_in,∇_uh,θ, ∇_th)
    ∇_uhᵀ = transpose(∇_uh)
    ϵ_skew = 0.5*(∇_uhᵀ - ∇_uh) - E_Matrx*θ
    if tr(ε_in) >= 0
        ψPos = 0.5*((λ + μ + (κ/2))*(tr(ε_in))^2 + (2*μ+κ)*((I4_dev ⊙ ε_in) ⊙ (I4_dev ⊙ ε_in))) + 0.5*(κ*(ϵ_skew ⊙ ϵ_skew)) + 0.5*γ*(∇_th ⋅ ∇_th)
    else
        ψPos = 0.5*((2*μ+κ)*((I4_dev ⊙ ε_in) ⊙ (I4_dev ⊙ ε_in))) + 0.5*(κ*(ϵ_skew ⊙ ϵ_skew)) + 0.5*γ*(∇_th ⋅ ∇_th)
    end
    return ψPos 
end
# Out:
# ψPos (generic function with 1 method)

# %%
function new_EnergyState(ψPlusPrev_in,ψhPos_in)
    ψPlus_in = ψhPos_in
        if ψPlus_in >= ψPlusPrev_in
            ψPlus_out = ψPlus_in
        else
            ψPlus_out = ψPlusPrev_in
        end
    true,ψPlus_out
end
# Out:
# new_EnergyState (generic function with 1 method)

# %%
function project(q,model,dΩ,order)
  reffe = ReferenceFE(lagrangian,Float64,order)
  V = FESpace(model,reffe,conformity=:L2)
  a(u,v) = ∫( u*v )*dΩ
  l(v) = ∫( v*q )*dΩ
  op = AffineFEOperator(a,l,V,V)
  qh = solve(op)
  qh
end
# Out:
# project (generic function with 1 method)

# %%
order = 1
degree = 2*order
# Out:
# 2

# %%
Ω = Triangulation(model)
dΩ = Measure(Ω,degree)
# Out:
# Measure()

# %%
sId = CellState(1.0,dΩ)
shId = project(sId,model,dΩ,order)
# Out:
# SingleFieldFEFunction():
#  num_cells: 139438
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 12401470399628560886

# %%
LoadTagId = get_tag_from_name(labels,"LoadLine")
Γ_Load = BoundaryTriangulation(model,tags = LoadTagId)
dΓ_Load = Measure(Γ_Load,degree)
n_Γ_Load = get_normal_vector(Γ_Load)
# Out:
# GenericCellField():
#  num_cells: 40
#  DomainStyle: ReferenceDomain()
#  Triangulation: BoundaryTriangulation()
#  Triangulation id: 8259286172234680183

# %%
reffe_PF = ReferenceFE(lagrangian,Float64,order)
V0_PF = TestFESpace(model,reffe_PF;conformity=:H1)
sh = zero(V0_PF)
# Out:
# SingleFieldFEFunction():
#  num_cells: 139438
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 12401470399628560886

# %%
reffe_theta = ReferenceFE(lagrangian,Float64,order)
V0_theta  = TestFESpace(model,reffe_theta;
  conformity=:H1,
          dirichlet_tags=["DirichletBottom"])
θh = zero(V0_theta)
# Out:
# SingleFieldFEFunction():
#  num_cells: 139438
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 12401470399628560886

# %%
reffe_Disp = ReferenceFE(lagrangian,VectorValue{2,Float64},order)
        V0_Disp = TestFESpace(model,reffe_Disp;
          conformity=:H1,
          dirichlet_tags=["DirichletBottom","LoadLine"],
          dirichlet_masks=[(true,true), (true,true)])

uh = zero(V0_Disp)
# Out:
# SingleFieldFEFunction():
#  num_cells: 139438
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 12401470399628560886

# %%
V0 = MultiFieldFESpace([V0_Disp,V0_theta])
# Out:
# MultiFieldFESpace()

# %%
function  stepPhaseField(uh_in,ψPlusPrev_in)
    U_PF = TrialFESpace(V0_PF)
        a_PF(s,ϕ) = ∫( (Gc*lsp*(∇(ϕ)⋅ ∇(s))) + (2*s*ψPlusPrev_in*ϕ)  + ((Gc/lsp)*s*ϕ) )*dΩ
        b_PF(ϕ) = ∫( (Gc/lsp)*ϕ )*dΩ
        op_PF = AffineFEOperator(a_PF,b_PF,U_PF,V0_PF)
        sh_out = solve(op_PF)
    return sh_out
end
# Out:
# stepPhaseField (generic function with 1 method)

# %%
function Skw(u,θ)
    ∇ᵀ = transpose(∇(u))
    w = (0.5*(∇ᵀ - ∇(u)) - (E_Matrx*θ))
    return w
end
# Out:
# Skw (generic function with 1 method)

# %%
function stepDisp(uh_in,θ_in,sh_in,uApp)
        uApp1(x) = VectorValue(0.0,0.0)
        uApp2(x) = VectorValue(uApp,uApp)
        U_Disp = TrialFESpace(V0_Disp,[uApp1,uApp2])
        
        θApp1(x) = 0.0
        U_theta = TrialFESpace(V0_theta,[θApp1])
        U = MultiFieldFESpace([U_Disp,U_theta])

        a((u,θ),(w,v))  = ∫( (ε(w) ⊙ (σ_Bmod∘(ε(u),ε(uh_in),sh_in)) ) + ((Skw(w,v)) ⊙ (σ_Cmod∘(ε_Skw∘(∇(u),θ), sh_in)) ) + ((∇(v))⋅ (M_mod∘(∇(θ),sh_in))) - (v*((E_Matrx) ⊙ (σ_Cmod∘(ε_Skw∘(∇(u),θ),sh_in))) ))*dΩ
        b((w,v))= 0
        op_Disp = AffineFEOperator(a,b,U,V0)
        uh_out = solve(op_Disp)
        uh_out,phih_out = uh_out
    return uh_out, phih_out
end
# Out:
# stepDisp (generic function with 1 method)

# %%
cd("DoubleNotch_N0.5_l30.0")

# %%
uApp = 0
delu = 0.05/40
uAppMax = 0.05
innerMax = 10
count = 0
Load = Float64[]
Displacement = Float64[]

sPrev = CellState(1.0,dΩ)
sh = project(sPrev,model,dΩ,order)
ψPlusPrev = CellState(0.0,dΩ)
ψhPos = CellState(0.0,dΩ)
ψhPos_in = project(ψhPos,model,dΩ,order)

while uApp .< uAppMax 
        
    uApp = uApp .+ delu
    count = count .+ 1
    
    print("\n Entering displacemtent step$count :", float(uApp))
    
    for inner = 1:innerMax
        
        ψhPlusPrev = project(ψPlusPrev,model,dΩ,order)
        
        err = abs(sum(∫( Gc*lsp*∇(sh)⋅ ∇(sh) + 2*ψhPlusPrev*sh*sh  + (Gc/lsp)*sh*sh)*dΩ - ∫( (Gc/lsp)*sh)*dΩ))/abs(sum(∫( (Gc/lsp)*sh)*dΩ))
        print("\n Relative error = ",float(err))
        
        sh = stepPhaseField(uh,ψhPlusPrev)
        uh,θh = stepDisp(uh,θh,sh,uApp)
        
        ψhPos_in = ψPos∘(ε(uh),∇(uh),θh,∇(θh))      
        
        update_state!(new_EnergyState,ψPlusPrev,ψhPos_in)
        
        if err < 1e-8
            break 
        end
    end
    
    Node_Force = sum(∫( n_Γ_Load ⋅ (σ_Bmod∘(ε(uh),ε(uh),sh)) ) *dΓ_Load + ∫( n_Γ_Load ⋅ (σ_Cmod∘(ε_Skw∘(∇(uh),θh),sh) ) )  *dΓ_Load)
    
    push!(Load, Node_Force[2])
    push!(Displacement, uApp)
    if mod(count,10) == 0
         writevtk(Ω,"results_DoubleNotch_N0.5_l30.0_$count",cellfields=
        ["uh"=>uh,"s"=>sh ,"θ" => θh, "epsi"=>ε(uh),"Sig"=>(σ_Bmod∘(ε(uh),ε(uh),sh))])
    end
end
# Out:
#  Entering displacemtent step1 :0.00125
#  Relative error = 3.202033167584182e-17
#  Entering displacemtent step2 :0.0025
#  Relative error = 2.8765049867466456e-5
#  Relative error = 8.628848365636716e-5
#  Relative error = 2.0402831665689e-8
#  Relative error = 8.164361726262558e-11
# ┌ Warning: detected extension '.0_2' does not correspond to dataset type.
# │ Appending '.vtu' to filename.
# └ @ WriteVTK /home/akash/.julia/packages/WriteVTK/UoUwH/src/WriteVTK.jl:112
#  Entering displacemtent step3 :0.00375
#  Relative error = 4.3593693230772667e-13
#  Entering displacemtent step4 :0.005
#  Relative error = 0.00014376021493713845
#  Relative error = 0.00020121501081624526
#  Relative error = 1.918526849978783e-7
#  Relative error = 3.0950154488752554e-9
# ┌ Warning: detected extension '.0_4' does not correspond to dataset type.
# │ Appending '.vtu' to filename.
# └ @ WriteVTK /home/akash/.julia/packages/WriteVTK/UoUwH/src/WriteVTK.jl:112
#  Entering displacemtent step5 :0.00625
#  Relative error = 6.66575487173805e-11
#  Entering displacemtent step6 :0.007500000000000001
#  Relative error = 0.00025836809535734597
#  Relative error = 0.0003158004526243363
#  Relative error = 6.911911000715714e-7
#  Relative error = 2.548826689555258e-8
#  Relative error = 1.253833406850672e-9
# ┌ Warning: detected extension '.0_6' does not correspond to dataset type.
# │ Appending '.vtu' to filename.
# └ @ WriteVTK /home/akash/.julia/packages/WriteVTK/UoUwH/src/WriteVTK.jl:112
#  Entering displacemtent step7 :0.00875
#  Relative error = 6.642997533264422e-11
#  Entering displacemtent step8 :0.01
#  Relative error = 0.0003721723302303806
#  Relative error = 0.00042982103519915993
#  Relative error = 1.727260993099282e-6
#  Relative error = 1.1597646750996134e-7
#  Relative error = 1.0370660507949748e-8
#  Relative error = 9.986997418021608e-10
# ┌ Warning: detected extension '.0_8' does not correspond to dataset type.
# │ Appending '.vtu' to filename.
# └ @ WriteVTK /home/akash/.julia/packages/WriteVTK/UoUwH/src/WriteVTK.jl:112
#  Entering displacemtent step9 :0.01125
#  Relative error = 9.866216342110125e-11
#  Entering displacemtent step10 :0.012499999999999999
#  Relative error = 0.00048467182064293636
#  Relative error = 0.0005430382634437797
#  Relative error = 3.566953107467609e-6
#  Relative error = 3.865743764128412e-7
#  Relative error = 5.568600275927752e-8
#  Relative error = 8.640182319713967e-9
# ┌ Warning: detected extension '.0_10' does not correspond to dataset type.
# │ Appending '.vtu' to filename.
# └ @ WriteVTK /home/akash/.julia/packages/WriteVTK/UoUwH/src/WriteVTK.jl:112
#  Entering displacemtent step11 :0.013749999999999998
#  Relative error = 1.37567553345188e-9
#  Entering displacemtent step12 :0.014999999999999998
#  Relative error = 0.0005951907066159263
#  Relative error = 0.0006551872851308685
#  Relative error = 6.574161037305036e-6
# InterruptException:
#
# Stacktrace:
#   [1] σ_Bmod(ε::SymTensorValue{2, Float64, 3}, ε_in::SymTensorValue{2, Float64, 3}, s_in::Float64)
#     @ Main ./In[8]:3
#   [2] _broadcast_getindex_evalf
#     @ ./broadcast.jl:670 [inlined]
#   [3] _broadcast_getindex
#     @ ./broadcast.jl:643 [inlined]
#   [4] getindex
#     @ ./broadcast.jl:597 [inlined]
#   [5] macro expansion
#     @ ./broadcast.jl:961 [inlined]
#   [6] macro expansion
#     @ ./simdloop.jl:77 [inlined]
#   [7] copyto!
#     @ ./broadcast.jl:960 [inlined]
#   [8] copyto!
#     @ ./broadcast.jl:913 [inlined]
#   [9] materialize!
#     @ ./broadcast.jl:871 [inlined]
#  [10] materialize!
#     @ ./broadcast.jl:868 [inlined]
#  [11] broadcast!(::typeof(σ_Bmod), ::Array{SymTensorValue{2, Float64, 3}, 3}, ::Array{SymTensorValue{2, Float64, 3}, 3}, ::Vector{SymTensorValue{2, Float64, 3}}, ::Vector{Float64})
#     @ Base.Broadcast ./broadcast.jl:837
#  [12] evaluate!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/Maps.jl:162 [inlined]
#  [13] evaluate!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Fields/FieldArrays.jl:502 [inlined]
#  [14] evaluate!(::Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, ::Gridap.Fields.BroadcastingFieldOpMap{typeof(σ_Bmod)}, ::Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, ::Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, ::Gridap.Fields.MatrixBlock{Vector{Float64}})
#     @ Gridap.Fields ~/.julia/packages/Gridap/TyUsh/src/Fields/ArrayBlocks.jl:958
#  [15] evaluate!(::Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, ::Gridap.Fields.BroadcastingFieldOpMap{typeof(σ_Bmod)}, ::Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, ::Vector{SymTensorValue{2, Float64, 3}}, ::Vector{Float64})
#     @ Gridap.Fields ~/.julia/packages/Gridap/TyUsh/src/Fields/ArrayBlocks.jl:1025
#  [16] _getindex_and_call!(cgi::Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(σ_Bmod)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{SymTensorValue{2, Float64, 3}, Vector{SymTensorValue{2, Float64, 3}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}, Tuple{Gridap.Arrays.CachedVector{Int32, Vector{Int32}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{Float64}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Grid ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:340
#  [17] getindex!(cache::Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{SymTensorValue{2, Float64, 3}, Vector{SymTensorValue{2, Float64, 3}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}, Tuple{Gridap.Arrays.CachedVector{Int32, Vector{Int32}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{Float64}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214
#  [18] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(inner)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Gridap ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:332
#  [19] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [20] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(+)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Flo ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:331
#  [21] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [22] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(+)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{ ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:331
#  [23] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [24] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(-)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{ ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:331
#  [25] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [26] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Matrix{Float64}}, Matrix{Tuple{Gridap.Arrays.CachedMatrix{Float64, Matrix{Float64}}, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, gi::Gridap.Fields.IntegrationMap, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tup ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:337
#  [27] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [28] _getindex_and_call!(cgi::Tuple{Tuple{Gridap.Fields.VectorBlock{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Nothing}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, gi::Gridap.CellData.AttachDirichletMap, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Matrix{Float64}}, Matrix{Tuple{Gridap.Arrays.CachedMatrix{Float64, Matrix{Float64}}, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Ma ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:337
#  [29] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [30] _numeric_loop_matvec!(A::Gridap.Algebra.InserterCSC{Float64, Int64}, b::Vector{Float64}, caches::Tuple{Matrix{Nothing}, Vector{Nothing}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.VectorBlock{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Nothing}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Matrix{Float64}}, Matrix{Tuple{Gridap.Arrays.CachedMatrix{Float64, Matrix{Float64}}, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}, Vector{Gridap.Arrays.CachedMatrix{SymTensorValue{2, Float64, 3}, Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{SymTensorValue{2, Float64, 3}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, ...
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/SparseMatrixAssemblers.jl:363
#  [31] numeric_loop_matrix_and_vector!(A::Gridap.Algebra.InserterCSC{Float64, Int64}, b::Vector{Float64}, a::Gridap.FESpaces.GenericSparseMatrixAssembler, data::Tuple{Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/SparseMatrixAssemblers.jl:349
#  [32] assemble_matrix_and_vector(a::Gridap.FESpaces.GenericSparseMatrixAssembler, data::Tuple{Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/SparseMatrixAssemblers.jl:137
#  [33] AffineFEOperator(weakform::Gridap.FESpaces.var"#60#61"{var"#a#8"{Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}}, var"#b#9"}, trial::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, test::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, assem::Gridap.FESpaces.GenericSparseMatrixAssembler)
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/AffineFEOperators.jl:38
#  [34] AffineFEOperator(::Function, ::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, ::Vararg{MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/AffineFEOperators.jl:47
#  [35] AffineFEOperator(::var"#a#8"{Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}}, ::var"#b#9", ::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, ::Vararg{MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/AffineFEOperators.jl:51
#  [36] stepDisp(uh_in::Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, θ_in::Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, sh_in::Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, uApp::Float64)
#     @ Main ./In[27]:12
#  [37] top-level scope
#     @ ./In[29]:30
#  [38] eval
#     @ ./boot.jl:368 [inlined]
#  [39] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1428

# %%
writevtk(Ω,"results_DoubleNotch_N0.5_l30.0_$count",cellfields=
        ["uh"=>uh,"s"=>sh ,"θ" => θh, "epsi"=>ε(uh)])
# Out:
# ┌ Warning: detected extension '.0_12' does not correspond to dataset type.
# │ Appending '.vtu' to filename.
# └ @ WriteVTK /home/akash/.julia/packages/WriteVTK/UoUwH/src/WriteVTK.jl:112
# (["results_DoubleNotch_N0.5_l30.0_12.vtu"],)

# %%
plot(Displacement,Load*1e-3)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fe3ece7b2b0>

# %%
cd("../DispLoadData_DoubleNotch_Vol-Dev")

# %%
using DelimitedFiles
Disp = writedlm( "DispDataDoubleNotchSpectral_N0.5_l30.0.csv",  Displacement, ',')
Force = writedlm("LoadDataDoubleNotchSpectral_N0.5_l30.0.csv",  Load, ',')
