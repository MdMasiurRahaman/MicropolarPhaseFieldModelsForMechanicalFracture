# %%
using Gmsh: gmsh
using Gridap
using GridapGmsh
using Gridap.TensorValues
using Plots
using LinearAlgebra

# %%
I2 = SymTensorValue{2,Float64}(1.0 ,0.0 ,1.0)
I4 = I2⊗I2
I4_sym = one(SymFourthOrderTensorValue{2,Float64})
I4_vol = (1.0/2)*I4
I4_dev = I4_sym  - I4_vol
# Out:
# SymFourthOrderTensorValue{2, Float64, 9}(0.5, 0.0, -0.5, 0.0, 0.5, 0.0, -0.5, 0.0, 0.5)

# %%
const lsp = 0.0075
# Out:
# 0.0075

# %%
const L = 1
const H = 1
const CP = H/2
const CL = 0.5*L 
const CH = H/1000
const hfc = lsp/50
const hf = lsp/10
const h = 50*hf 
const FMR = 5*lsp
 
gmsh.initialize()
gmsh.option.setNumber("General.Terminal", 1)
gmsh.model.geo.addPoint(0.0, 0.0, 0.0, h, 1)  
gmsh.model.geo.addPoint(L, 0.0, 0.0, h, 2) 
gmsh.model.geo.addPoint(L, H, 0.0, h, 3) 
gmsh.model.geo.addPoint(0.0, H, 0.0, h, 4)
gmsh.model.geo.addPoint(0.0, CP + CH, 0.0, h, 5)
gmsh.model.geo.addPoint(CL, CP + CH, 0.0, hfc, 6)
gmsh.model.geo.addPoint(CL, CP - CH, 0.0, hfc, 7)
gmsh.model.geo.addPoint(0.0, CP - CH, 0.0, h, 8)

gmsh.model.geo.addLine(1, 2, 1)
gmsh.model.geo.addLine(2, 3, 2)
gmsh.model.geo.addLine(3, 4, 3)
gmsh.model.geo.addLine(4, 5, 4)
gmsh.model.geo.addLine(5, 6, 5)
gmsh.model.geo.addLine(6, 7, 6)
gmsh.model.geo.addLine(7, 8, 7)
gmsh.model.geo.addLine(8, 1, 8)
gmsh.model.geo.addCurveLoop([1,2,3,4,5,6,7,8],1) 
gmsh.model.geo.addPlaneSurface([1], 1)
gmsh.model.addPhysicalGroup(2, [1],1)
gmsh.model.addPhysicalGroup(1, [1],1)
gmsh.model.addPhysicalGroup(1, [3],2)
gmsh.model.setPhysicalName(2, 1, "Domain")
gmsh.model.setPhysicalName(1, 1, "DirichletBot")
gmsh.model.setPhysicalName(1, 2, "DirichletTop")


gmsh.model.mesh.field.add("Box", 11)
gmsh.model.mesh.field.setNumber(11, "VIn", hf)
gmsh.model.mesh.field.setNumber(11, "VOut", h)
gmsh.model.mesh.field.setNumber(11, "XMin", 0.95*CL)
gmsh.model.mesh.field.setNumber(11, "XMax", L)
gmsh.model.mesh.field.setNumber(11, "YMin", CP-FMR)
gmsh.model.mesh.field.setNumber(11, "YMax", CP+FMR)
gmsh.model.mesh.field.setAsBackgroundMesh(11)

gmsh.model.geo.synchronize()
gmsh.model.mesh.generate(2)
gmsh.write("SquarePlateWithEdgeNotch.msh")
gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Line)
# Info    : [ 70%] Meshing curve 6 (Line)
# Info    : [ 80%] Meshing curve 7 (Line)
# Info    : [ 90%] Meshing curve 8 (Line)
# Info    : Done meshing 1D (Wall 0.0105922s, CPU 0.010157s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 2.83566s, CPU 2.81564s)
# Info    : 71135 nodes 142276 elements
# Info    : Writing 'SquarePlateWithEdgeNotch.msh'...
# Info    : Done writing 'SquarePlateWithEdgeNotch.msh'
# Warning : Unknown entity of dimension 2 and tag 1 in physical group 1
# Warning : Unknown entity of dimension 1 and tag 1 in physical group 1
# Warning : Unknown entity of dimension 1 and tag 3 in physical group 2

# %%
model = GmshDiscreteModel("SquarePlateWithEdgeNotch.msh")
writevtk(model,"SquarePlateWithEdgeNotch")
# Out:
# Info    : Reading 'SquarePlateWithEdgeNotch.msh'...
# Info    : 17 entities
# Info    : 287005 nodes
# Info    : 573027 elements
# Info    : Done reading 'SquarePlateWithEdgeNotch.msh'
# 3-element Vector{Vector{String}}:
#  ["SquarePlateWithEdgeNotch_0.vtu"]
#  ["SquarePlateWithEdgeNotch_1.vtu"]
#  ["SquarePlateWithEdgeNotch_2.vtu"]

# %%
using Gridap.Geometry
labels = get_face_labeling(model)
dimension = 2
mat_tags = get_face_tag(labels,dimension)
# Out:
# 572827-element Vector{Int8}:
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  ⋮
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3

# %%
const E = 210e3
const ν = 0.3
G = E/(2*(1+ν))
l = 0.05
N = 0.5
Gc = 2.7

const η = 1e-15
# Out:
# 1.0e-15

# %%
μ = 53846.1538461538
κ = 53846.1538461538
λ = 121153.84615384605
γ = 807.692307692307
# Out:
# 807.692307692307

# %%
function σ_Bmod(ε, ε_in, s_in)
    if tr(ε_in) >= 0
        σM = (s_in^2 + η)*((λ + μ + (κ/2))*tr(ε)*one(ε) + (2*μ + κ)*(I4_dev ⊙ ε))
    else
        σM = (s_in^2 + η)*((2*μ + κ)*(I4_dev ⊙ ε)) + (λ + μ + (κ/2))*tr(ε)*one(ε)
    end
    return σM
end
# Out:
# σ_Bmod (generic function with 1 method)

# %%
E_Matrx = TensorValue(0,1,-1,0)
# Out:
# TensorValue{2, 2, Int64, 4}(0, 1, -1, 0)

# %%
function ε_Skw(∇,θ)
    ∇ᵀ = transpose(∇)
    w = (0.5*(∇ᵀ - ∇)) - (E_Matrx*θ)
    return w
end
# Out:
# ε_Skw (generic function with 1 method)

# %%
function σ_Cmod(ϵ_skew, s_in)
    σM = (s_in^2 + η)*(κ*ϵ_skew)
    return σM
end
# Out:
# σ_Cmod (generic function with 1 method)

# %%
function M_mod(∇, s_in)
    M = (s_in^2 + η)*(γ*∇)
    return M
end
# Out:
# M_mod (generic function with 1 method)

# %%
function ψPos(ε_in,∇_uh,θ, ∇_th)
    ∇_uhᵀ = transpose(∇_uh)
    ϵ_skew = 0.5*(∇_uhᵀ - ∇_uh) - E_Matrx*θ
    if tr(ε_in) >= 0
        ψPos = 0.5*((λ + μ + (κ/2))*(tr(ε_in))^2 + (2*μ+κ)*((I4_dev ⊙ ε_in) ⊙ (I4_dev ⊙ ε_in))) + 0.5*(κ*(ϵ_skew ⊙ ϵ_skew)) + 0.5*γ*(∇_th ⋅ ∇_th)
    else
        ψPos = 0.5*((2*μ+κ)*((I4_dev ⊙ ε_in) ⊙ (I4_dev ⊙ ε_in))) + 0.5*(κ*(ϵ_skew ⊙ ϵ_skew)) + 0.5*γ*(∇_th ⋅ ∇_th)
    end
    return ψPos 
end
# Out:
# ψPos (generic function with 1 method)

# %%
function new_EnergyState(ψPlusPrev_in,ψhPos_in)
    ψPlus_in = ψhPos_in
    if ψPlus_in >= ψPlusPrev_in
        ψPlus_out = ψPlus_in
    else
        ψPlus_out = ψPlusPrev_in
    end
    true,ψPlus_out
end
# Out:
# new_EnergyState (generic function with 1 method)

# %%
function project(q,model,dΩ,order)
  reffe = ReferenceFE(lagrangian,Float64,order)
  V = FESpace(model,reffe,conformity=:L2)
  a(u,v) = ∫( u*v )*dΩ
  l(v) = ∫( v*q )*dΩ
  op = AffineFEOperator(a,l,V,V)
  qh = solve(op)
  qh
end
# Out:
# project (generic function with 1 method)

# %%
order = 1
degree = 2*order
# Out:
# 2

# %%
Ω = Triangulation(model)
dΩ = Measure(Ω,degree)
# Out:
# Measure()

# %%
sId = CellState(1.0,dΩ)
shId = project(sId,model,dΩ,order)
# Out:
# SingleFieldFEFunction():
#  num_cells: 572827
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 4825900959742382055

# %%
LoadTagId = get_tag_from_name(labels,"DirichletTop")
Γ_Load = BoundaryTriangulation(model,tags = LoadTagId)
dΓ_Load = Measure(Γ_Load,degree)
n_Γ_Load = get_normal_vector(Γ_Load)
# Out:
# GenericCellField():
#  num_cells: 100
#  DomainStyle: ReferenceDomain()
#  Triangulation: BoundaryTriangulation()
#  Triangulation id: 6641911023157496489

# %%
reffe_PF = ReferenceFE(lagrangian,Float64,order)
V0_PF = TestFESpace(model,reffe_PF;conformity=:H1)
sh = zero(V0_PF)
# Out:
# SingleFieldFEFunction():
#  num_cells: 572827
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 4825900959742382055

# %%
reffe_theta = ReferenceFE(lagrangian,Float64,order)
V0_theta  = TestFESpace(model,reffe_theta; conformity=:H1,dirichlet_tags=["DirichletBot"])
θh = zero(V0_theta)
# Out:
# SingleFieldFEFunction():
#  num_cells: 572827
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 4825900959742382055

# %%
reffe_Disp = ReferenceFE(lagrangian,VectorValue{2,Float64},order)
        V0_Disp = TestFESpace(model,reffe_Disp;
          conformity=:H1,
          dirichlet_tags=["DirichletBot","DirichletTop"],
          dirichlet_masks=[(true,true), (false,true)])

uh = zero(V0_Disp)
# Out:
# SingleFieldFEFunction():
#  num_cells: 572827
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 4825900959742382055

# %%
V0 = MultiFieldFESpace([V0_Disp,V0_theta])
# Out:
# MultiFieldFESpace()

# %%
function  stepPhaseField(uh_in,ψPlusPrev_in)
        U_PF = TrialFESpace(V0_PF)
        a_PF(s,ϕ) = ∫( (Gc*lsp*∇(ϕ)⋅ ∇(s)) + (2*ψPlusPrev_in*s*ϕ)  + ((Gc/lsp)*s*ϕ) )*dΩ
        b_PF(ϕ) = ∫( (Gc/lsp)*ϕ )*dΩ
        op_PF = AffineFEOperator(a_PF,b_PF,U_PF,V0_PF)
        sh_out = solve(op_PF)
        return sh_out
end
# Out:
# stepPhaseField (generic function with 1 method)

# %%
function Skw(u,θ)
    ∇ᵀ = transpose(∇(u))
    w = (0.5*(∇ᵀ) - (E_Matrx*θ))
    return w
end
# Out:
# Skw (generic function with 1 method)

# %%
function   stepDisp(uh_in,θ_in,sh_in,uApp)
        uApp1(x) = VectorValue(0.0,0.0)
        uApp2(x) = VectorValue(0.0,uApp)
        U_Disp = TrialFESpace(V0_Disp,[uApp1,uApp2])
        
        θApp1(x) = 0.0
        U_theta = TrialFESpace(V0_theta,[θApp1])
        U = MultiFieldFESpace([U_Disp,U_theta ])

        a((u,θ),(w,v))  = ∫( ((Skw(w,v)) ⊙ (σ_Bmod∘(ε(u),ε(uh_in),sh_in)) ) + ((Skw(w,v)) ⊙ (σ_Cmod∘(ε_Skw∘(∇(u),θ), sh_in)) ) + ((∇(v))⋅ (M_mod∘(∇(θ),sh_in))) - (v*((E_Matrx) ⊙ (σ_Cmod∘(ε_Skw∘(∇(u),θ),sh_in))) ))*dΩ
        b((w,v))= 0
        op_Disp = AffineFEOperator(a,b,U,V0)
        uh_out = solve(op_Disp)
        uh_out,phih_out = uh_out
    return uh_out, phih_out
end
# Out:
# stepDisp (generic function with 1 method)

# %%
cd("Results_N0.5_l0.05")

# %%
uApp = 0
delu = 0.01/50
uAppMax = 0.01
innerMax = 10
count = 0
Load = Float64[]
Displacement = Float64[]

sPrev = CellState(1.0,dΩ)
sh = project(sPrev,model,dΩ,order)
ψPlusPrev = CellState(0.0,dΩ)
ψhPos = CellState(0.0,dΩ)
ψhPos_in = project(ψhPos,model,dΩ,order)

while count .< 175 

    count = count .+ 1
    if count <= 50
        uApp = uApp .+ delu
    elseif count <= 100
        uApp = uApp .- delu
    else
        delu = 0.01/150
        uApp = uApp .- delu
    end
   
    print("\n Entering displacemtent step$count :", float(uApp))
    
   for inner = 1:innerMax
        
        ψhPlusPrev = project(ψPlusPrev,model,dΩ,order)
        
        err = abs(sum(∫( Gc*lsp*∇(sh)⋅ ∇(sh) + 2*ψhPlusPrev*sh*sh  + (Gc/lsp)*sh*sh)*dΩ - ∫( (Gc/lsp)*sh)*dΩ))/abs(sum(∫( (Gc/lsp)*sh)*dΩ))
        print("\n Relative error = ",float(err))
        
        sh = stepPhaseField(uh,ψhPlusPrev) 
        uh,θh = stepDisp(uh,θh,sh,uApp)
        
        ψhPos_in = ψPos∘(ε(uh),∇(uh),θh,∇(θh))      
        
        update_state!(new_EnergyState,ψPlusPrev,ψhPos_in)
        
        if err < 1e-8
            break 
        end
    end
    
    Node_Force = sum(∫( n_Γ_Load ⋅ (σ_Bmod∘(ε(uh),ε(uh),sh)) ) *dΓ_Load + ∫( n_Γ_Load ⋅ (σ_Cmod∘(ε_Skw∘(∇(uh),θh),sh) ) )  *dΓ_Load)
    
    push!(Load, Node_Force[2])
    push!(Displacement, uApp)
    if mod(count,10) == 0
         writevtk(Ω,"results_PhaseField_Mode1_N0.5l0.05_$count",cellfields=
        ["uh"=>uh,"s"=>sh ,"θ" => θh, "epsi"=>ε(uh)])
    end
end
# Out:
#  Entering displacemtent step1 :0.0002
#  Relative error = 2.80226245411563e-17
#  Entering displacemtent step2 :0.0004
#  Relative error = 1.6001500132094682e-5
#  Relative error = 4.800173572833578e-5
# InterruptException:
#
# Stacktrace:
#   [1] ε_Skw(∇::TensorValue{2, 2, Float64, 4}, θ::Float64)
#     @ Main ./In[11]:3
#   [2] evaluate!(cache::Gridap.Arrays.CachedArray{TensorValue{2, 2, Float64, 4}, 3, Array{TensorValue{2, 2, Float64, 4}, 3}}, f::Gridap.Fields.BroadcastingFieldOpMap{typeof(ε_Skw)}, a::Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}, b::Array{Float64, 3})
#     @ Gridap.Fields ~/.julia/packages/Gridap/TyUsh/src/Fields/FieldArrays.jl:516
#   [3] evaluate!(cache::Tuple{Gridap.Fields.MatrixBlock{Array{TensorValue{2, 2, Float64, 4}, 3}}, Matrix{Gridap.Arrays.CachedArray{TensorValue{2, 2, Float64, 4}, 3, Array{TensorValue{2, 2, Float64, 4}, 3}}}, Matrix{Gridap.Arrays.CachedArray{TensorValue{2, 2, Float64, 4}, 3, Array{TensorValue{2, 2, Float64, 4}, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, k::Gridap.Fields.BroadcastingFieldOpMap{typeof(ε_Skw)}, f::Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, g::Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{Float64}, Float64}})
#     @ Gridap.Fields ~/.julia/packages/Gridap/TyUsh/src/Fields/ArrayBlocks.jl:843
#   [4] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{TensorValue{2, 2, Float64, 4}, 3}}, Matrix{Gridap.Arrays.CachedArray{TensorValue{2, 2, Float64, 4}, 3, Array{TensorValue{2, 2, Float64, 4}, 3}}}, Matrix{Gridap.Arrays.CachedArray{TensorValue{2, 2, Float64, 4}, 3, Array{TensorValue{2, 2, Float64, 4}, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(ε_Skw)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}}}, Nothing}, args::Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Gridap.Fields.TransposeMap, 1, Tuple{Base.OneTo{Int64}}}, Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, 1, Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Gridap.Fields.BlockMap{1}, 1, Tuple{Base.OneTo{Int64}}}, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, 1, Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Gridap.Fields.BroadcastingFieldOpMap{typeof(dot)}, 1, Tuple{Base.OneTo{Int64}}}, Matrix{TensorValue{2, 2, Float64, 4}}, 1, Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Broadcasting{typeof(Gridap.Fields.pinvJt)}, 1, Tuple{Base.OneTo{Int64}}}, Vector{TensorValue{2, 2, Float64, 4}}, 1, Tuple{Gridap.Arrays.LazyArray{Gridap.Arrays.LazyArray{FillArrays.Fill{typeof(Gridap.Fields.constant_field), 1, Tuple{Base.OneTo{Int64}}}, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}, 1, Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Gridap.Fields.LinearCombinationMap{Colon}, 1, Tuple{Base.OneTo{Int64}}}, TensorValue{2, 2, Float64, 4}, 1, Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Broadcasting{Reindex{Vector{VectorValue{2, Float64}}}}, 1, Tuple{Base.OneTo{Int64}}}, Vector{VectorValue{2, Float64}}, 1, Tuple{Gridap.Arrays.Table{Int64, Vector{Int64}, Vector{Int32}}}}, Gridap.Arrays.CompressedArray{Vector{VectorValue{2, Float64}}, 1, Vector{Vector{VectorValue{2, Float64}}}, Vector{Int8}}}}}}, Vector{TensorValue{2, 2, Float64, 4}}, 1, Tuple{Gridap.Arrays.CompressedArray{Vector{VectorValue{2, Float64}}, 1, Vector{Vector{VectorValue{2, Float64}}}, Vector{Int8}}}}}}, Gridap.Arrays.CompressedArray{Matrix{TensorValue{2, 2, Float64, 4}}, 1, Vector{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Int8}}}}}}}}, Gridap.Arrays.CompressedArray{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Ma ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:333
#   [5] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#   [6] _getindex_and_call!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:331 [inlined]
#   [7] getindex!(cache::Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{TensorValue{2, 2, Float64, 4}, 3}}, Matrix{Gridap.Arrays.CachedArray{TensorValue{2, 2, Float64, 4}, 3, Array{TensorValue{2, 2, Float64, 4}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{TensorValue{2, 2, Float64, 4}, 3}}, Matrix{Gridap.Arrays.CachedArray{TensorValue{2, 2, Float64, 4}, 3, Array{TensorValue{2, 2, Float64, 4}, 3}}}, Matrix{Gridap.Arrays.CachedArray{TensorValue{2, 2, Float64, 4}, 3, Array{TensorValue{2, 2, Float64, 4}, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Array{TensorValue{2, 2, Float64, 4}, 3}}}}, Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}, Tuple{Gridap.Arrays.CachedVector{Int32, Vector{Int32}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{Float64}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{Float64}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.MatrixBlock{Array{TensorValue{2, 2, Float64, 4}, 3}}}}, a::Gridap.Arrays.LazyArray{FillArrays.Fill{Gridap.Fields.BroadcastingFieldOpMap{typeof(σ_Cmod)}, 1, Tuple{Base.OneTo{Int64}}}, Gridap.Fields.MatrixBlock{Array{TensorValue{2, 2, Float64, 4}, 3}}, 1, Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Gridap.Fields.BroadcastingFieldOpMap{typeof(ε_Skw)}, 1, Tuple{Base.OneTo{Int64}}}, Gridap.Fields.MatrixBlock{Array{TensorValue{2, 2, Float64, 4}, 3}}, 1, Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Gridap.Fields.TransposeMap, 1, Tuple{Base.OneTo{Int64}}}, Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, 1, Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Gridap.Fields.BlockMap{1}, 1, Tuple{Base.OneTo{Int64}}}, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, 1, Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Gridap.Fields.BroadcastingFieldOpMap{typeof(dot)}, 1, Tuple{Base.OneTo{Int64}}}, Matrix{TensorValue{2, 2, Float64, 4}}, 1, Tuple{Gridap.Arrays.LazyArray{FillArrays.Fill{Broadcasting{typeof(Gridap.Fields.pinvJt)}, 1, Tuple{Base.OneTo{Int64}}}, Vector{TensorValue{2, 2, Float64, 4}}, 1, Tuple{Gridap.Arrays. ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214
#   [8] _getindex_and_call!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:332 [inlined]
#   [9] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [10] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(+)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Nothing, Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float64, 4}}}, Matrix{Nothing}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Grida ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:332
#  [11] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [12] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(+)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Nothing, Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Gridap.Fields.TransposeFieldIndices{Matrix{TensorValue{2, 2, Float64, 4}}, TensorValue{2, 2, Float ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:331
#  [13] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [14] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, gi::Gridap.Fields.BroadcastingFieldOpMap{typeof(-)}, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Nothing, Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixBlock{Vector{SymTensorValue{2, Float64, 3}}}, Gridap.Fields.MatrixBlock{Vector{Float64}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:331
#  [15] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [16] _getindex_and_call!(cgi::Tuple{Gridap.Fields.MatrixBlock{Matrix{Float64}}, Matrix{Tuple{Gridap.Arrays.CachedMatrix{Float64, Matrix{Float64}}, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, gi::Gridap.Fields.IntegrationMap, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Nothing, Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Matrix{Gridap.Arrays.CachedArray{SymTensorValue{2, Float64, 3}, 3, Array{SymTensorValue{2, Float64, 3}, 3}}}}, Tuple{Gridap.Fields.MatrixBlock{Array{SymTensorValue{2, Float64, 3}, 3}}, Gridap.Fields.MatrixB ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:337
#  [17] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [18] _getindex_and_call!(cgi::Tuple{Tuple{Gridap.Fields.VectorBlock{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Nothing}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, gi::Gridap.CellData.AttachDirichletMap, cf::Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Matrix{Float64}}, Matrix{Tuple{Gridap.Arrays.CachedMatrix{Float64, Matrix{Float64}}, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Nothing, Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}} ...
#     @ Gridap.Arrays ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:337
#  [19] getindex!
#     @ ~/.julia/packages/Gridap/TyUsh/src/Arrays/LazyArrays.jl:214 [inlined]
#  [20] _numeric_loop_matvec!(A::Gridap.Algebra.InserterCSC{Float64, Int64}, b::Vector{Float64}, caches::Tuple{Matrix{Nothing}, Vector{Nothing}, Tuple{Tuple{Nothing, Tuple{Tuple{Gridap.Fields.VectorBlock{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Nothing}}}, Tuple{Gridap.Fields.VectorBlock{Vector{Float64}}, Vector{Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Matrix{Float64}}, Matrix{Tuple{Gridap.Arrays.CachedMatrix{Float64, Matrix{Float64}}, Gridap.Arrays.CachedVector{Float64, Vector{Float64}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.MatrixBlock{Array{Float64, 3}}, Matrix{Gridap.Arrays.CachedArray{Float64, 3, Array{Float64, 3}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Nothing, Tuple{Tuple{Nothing, Tuple{Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Vector{Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedMatrix{TensorValue{2, 2, Float64, 4}, Matrix{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Tuple{Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Nothing, Tuple{Tuple{Tuple{Nothing, Gridap.Arrays.CachedVector{VectorValue{2, Float64}, Vector{VectorValue{2, Float64}}}, Tuple{Gridap.Arrays.CachedVector{Int64, Vector{Int64}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{VectorValue{2, Float64}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, TensorValue{2, 2, Float64, 4}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.ConstantField{TensorValue{2, 2, Float64, 4}}}}, Gridap.Arrays.CachedVector{TensorValue{2, 2, Float64, 4}, Vector{TensorValue{2, 2, Float64, 4}}}, Tuple{Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Vector{TensorValue{2, 2, Float64, 4}}}}, Nothing}}, Gridap.Arrays.IndexItemPair{Int64, Matrix{TensorValue{2, 2, Float64, 4}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}}}, Gridap.Arrays.IndexItemPair{Int64, Gridap.Fields.VectorBlock{Matrix{TensorValue{2, 2, Float64, 4}}}}}, Nothing}}, Gridap.Array ...
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/SparseMatrixAssemblers.jl:363
#  [21] numeric_loop_matrix_and_vector!(A::Gridap.Algebra.InserterCSC{Float64, Int64}, b::Vector{Float64}, a::Gridap.FESpaces.GenericSparseMatrixAssembler, data::Tuple{Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/SparseMatrixAssemblers.jl:349
#  [22] assemble_matrix_and_vector(a::Gridap.FESpaces.GenericSparseMatrixAssembler, data::Tuple{Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}, Vector{Any}}, Tuple{Vector{Any}, Vector{Any}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/SparseMatrixAssemblers.jl:137
#  [23] AffineFEOperator(weakform::Gridap.FESpaces.var"#60#61"{var"#a#8"{Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}}, var"#b#9"}, trial::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, test::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, assem::Gridap.FESpaces.GenericSparseMatrixAssembler)
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/AffineFEOperators.jl:38
#  [24] AffineFEOperator(::Function, ::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, ::Vararg{MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/AffineFEOperators.jl:47
#  [25] AffineFEOperator(::var"#a#8"{Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}}, ::var"#b#9", ::MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}, ::Vararg{MultiFieldFESpace{Gridap.MultiField.ConsecutiveMultiFieldStyle, Gridap.FESpaces.UnConstrained, Vector{Float64}}})
#     @ Gridap.FESpaces ~/.julia/packages/Gridap/TyUsh/src/FESpaces/AffineFEOperators.jl:51
#  [26] stepDisp(uh_in::Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, θ_in::Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, sh_in::Gridap.FESpaces.SingleFieldFEFunction{Gridap.CellData.GenericCellField{ReferenceDomain}}, uApp::Float64)
#     @ Main ./In[27]:12
#  [27] top-level scope
#     @ ./In[29]:37
#  [28] eval
#     @ ./boot.jl:368 [inlined]
#  [29] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1428

# %%
writevtk(Ω,"results_PhaseField_Mode1_N0.5l0.05_$count",cellfields=
        ["uh"=>uh,"s"=>sh ,"θ" => θh, "epsi"=>ε(uh)])
# Out:
# ┌ Warning: detected extension '.05_2' does not correspond to dataset type.
# │ Appending '.vtu' to filename.
# └ @ WriteVTK /home/akash/.julia/packages/WriteVTK/UoUwH/src/WriteVTK.jl:112
# (["results_PhaseField_Mode1_N0.5l0.05_2.vtu"],)

# %%
Plots.plot(Displacement,Load)

# %%
cd("../DispLoadData_Mode1_Vol-Dev")

# %%
using DelimitedFiles
Disp = writedlm( "DispDataMode1_Vol-Dev_N0.5_l0.05.csv",  Displacement, ',')
Force = writedlm("LoadDataMode1_Vol-Dev_N0.5_l0.05.csv",  Load, ',')
